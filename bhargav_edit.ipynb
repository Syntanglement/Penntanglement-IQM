# %%
# %pip install qiskit
# Out:
# Requirement already satisfied: qiskit in ./.venv/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in ./.venv/lib/python3.11/site-packages (from qiskit) (2.0.0)
# Requirement already satisfied: scipy>=1.5 in ./.venv/lib/python3.11/site-packages (from qiskit) (1.15.3)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.11/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from qiskit) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade pip
# !pip install "iqm-client[qiskit]"
# !pip install qrisp[iqm]
# !pip install numpy==2.0
# !pip install matplotlib
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.11/site-packages (26.0)
# Requirement already satisfied: iqm-client[qiskit] in ./.venv/lib/python3.11/site-packages (33.0.3)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (2.0.0)
# Requirement already satisfied: packaging==24.1 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (2.12.5)
# Requirement already satisfied: requests==2.32.3 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (2.32.3)
# Requirement already satisfied: iqm-pulse<13,>=12.7.3 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (12.7.3)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.3 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (12.0.3)
# Requirement already satisfied: qiskit<2.2,>=1.0 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (2.1.2)
# Requirement already satisfied: qiskit-aer<0.18,>=0.13.1 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]) (0.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests==2.32.3->iqm-client[qiskit]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests==2.32.3->iqm-client[qiskit]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests==2.32.3->iqm-client[qiskit]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests==2.32.3->iqm-client[qiskit]) (2026.1.4)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (2.22)
# Requirement already satisfied: python-rapidjson==1.20 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (1.20)
# Requirement already satisfied: jinja2==3.0.3 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (3.0.3)
# Requirement already satisfied: scipy<1.16,>=1.11.4 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (1.15.3)
# Requirement already satisfied: scipy-stubs in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (1.17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from jinja2==3.0.3->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (3.0.3)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in ./.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (4.25.8)
# Requirement already satisfied: types-protobuf in ./.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (6.32.1.20251210)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.76.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (6.0.3)
# Requirement already satisfied: types-requests in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (2.32.4.20260107)
# Requirement already satisfied: tqdm>=4.59.0 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (4.67.2)
# Requirement already satisfied: types-tqdm in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (4.67.0.20250809)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.3 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (27.4.3)
# Requirement already satisfied: typing-extensions~=4.12 in ./.venv/lib/python3.11/site-packages (from grpcio<2.0,>=1.65.4->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (4.15.0)
# Requirement already satisfied: python-dotenv==0.21.1 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (2024.10.0)
# Requirement already satisfied: ruamel-yaml==0.17.32 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (0.2.8)
# Requirement already satisfied: six==1.16.0 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.16.0)
# Requirement already satisfied: types-six in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.17.0.20251009)
# Requirement already satisfied: pandas>=2.1 in ./.venv/lib/python3.11/site-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (3.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.72.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (1.27.0)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (0.48b0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit<2.2,>=1.0->iqm-client[qiskit]) (0.17.1)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.11/site-packages (from qiskit<2.2,>=1.0->iqm-client[qiskit]) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit<2.2,>=1.0->iqm-client[qiskit]) (5.6.0)
# Requirement already satisfied: psutil>=5 in ./.venv/lib/python3.11/site-packages (from qiskit-aer<0.18,>=0.13.1->iqm-client[qiskit]) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./.venv/lib/python3.11/site-packages (from qiskit-aer<0.18,>=0.13.1->iqm-client[qiskit]) (2.9.0.post0)
# Requirement already satisfied: wrapt<3,>=1.10 in ./.venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]) (2.0.1)
# Requirement already satisfied: optype<0.16,>=0.14.0 in ./.venv/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (0.15.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in ./.venv/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]) (20251206.2.3)
# Collecting numpy<3.0,>=1.26.4 (from iqm-client[qiskit])
#   Using cached numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Using cached numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed numpy-2.3.5
# Requirement already satisfied: qrisp[iqm] in ./.venv/lib/python3.11/site-packages (0.7.19)
# Requirement already satisfied: numpy>=2.0 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.3.5)
# Requirement already satisfied: sympy<=1.13 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (1.13.0)
# Requirement already satisfied: qiskit>=0.44.0 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.1.2)
# Requirement already satisfied: matplotlib>=3.5.1 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (3.10.8)
# Requirement already satisfied: scipy>=1.10.0 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (1.15.3)
# Requirement already satisfied: numba in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (0.63.1)
# Requirement already satisfied: networkx in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (3.6.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (4.67.2)
# Requirement already satisfied: dill in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (0.4.1)
# Requirement already satisfied: flask<2.3.0 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.2.5)
# Requirement already satisfied: waitress in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (3.0.2)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.32.3)
# Requirement already satisfied: psutil in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (7.2.2)
# Requirement already satisfied: jax==0.7.1 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (0.7.1)
# Requirement already satisfied: jaxlib==0.7.1 in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (0.7.1)
# Requirement already satisfied: iqm-client[qiskit] in ./.venv/lib/python3.11/site-packages (from qrisp[iqm]) (33.0.3)
# Requirement already satisfied: ml_dtypes>=0.5.0 in ./.venv/lib/python3.11/site-packages (from jax==0.7.1->qrisp[iqm]) (0.5.4)
# Requirement already satisfied: opt_einsum in ./.venv/lib/python3.11/site-packages (from jax==0.7.1->qrisp[iqm]) (3.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in ./.venv/lib/python3.11/site-packages (from flask<2.3.0->qrisp[iqm]) (3.1.5)
# Requirement already satisfied: Jinja2>=3.0 in ./.venv/lib/python3.11/site-packages (from flask<2.3.0->qrisp[iqm]) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in ./.venv/lib/python3.11/site-packages (from flask<2.3.0->qrisp[iqm]) (2.2.0)
# Requirement already satisfied: click>=8.0 in ./.venv/lib/python3.11/site-packages (from flask<2.3.0->qrisp[iqm]) (8.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from sympy<=1.13->qrisp[iqm]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from Jinja2>=3.0->flask<2.3.0->qrisp[iqm]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->qrisp[iqm]) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (5.6.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (4.15.0)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.12.5)
# Requirement already satisfied: iqm-pulse<13,>=12.7.3 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (12.7.3)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.3 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (12.0.3)
# Requirement already satisfied: qiskit-aer<0.18,>=0.13.1 in ./.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (2026.1.4)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.22)
# Requirement already satisfied: python-rapidjson==1.20 in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.20)
# Requirement already satisfied: scipy-stubs in ./.venv/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.17.0.2)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in ./.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (4.25.8)
# Requirement already satisfied: types-protobuf in ./.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (6.32.1.20251210)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.76.0)
# Requirement already satisfied: types-requests in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (4.67.0.20250809)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.3 in ./.venv/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (27.4.3)
# Requirement already satisfied: python-dotenv==0.21.1 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2024.10.0)
# Requirement already satisfied: ruamel-yaml==0.17.32 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.2.8)
# Requirement already satisfied: types-six in ./.venv/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.17.0.20251009)
# Requirement already satisfied: pandas>=2.1 in ./.venv/lib/python3.11/site-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.3->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (3.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.72.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.27.0)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in ./.venv/lib/python3.11/site-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.48b0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.4.2)
# Requirement already satisfied: wrapt<3,>=1.10 in ./.venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.0.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.11/site-packages (from numba->qrisp[iqm]) (0.46.0)
# Requirement already satisfied: optype<0.16,>=0.14.0 in ./.venv/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.15.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in ./.venv/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.3->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (20251206.2.3)
# Collecting numpy==2.0
#   Using cached numpy-2.0.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Using cached numpy-2.0.0-cp311-cp311-macosx_14_0_arm64.whl (5.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numpy-typing-compat 20251206.2.3 requires numpy<2.4,>=2.3, but you have numpy 2.0.0 which is incompatible.
# Successfully installed numpy-2.0.0
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.11/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pylatexenc in ./.venv/lib/python3.11/site-packages (2.10)

# %%
from qiskit import QuantumCircuit

def create_ghz_circuit(qubit_count):
    qc = QuantumCircuit(qubit_count)

    # Build the GHZ circuit
    qc.h(0)
    for qb in range(1, qubit_count):
        qc.cx(0, qb)

    return qc

# %%
def basis_measurement(qc: QuantumCircuit, basis: str):
    """Adds measurement in the specified basis to the circuit."""
    n = qc.num_qubits
    meas_circ = QuantumCircuit(n, n)
    meas_circ.compose(qc, range(n), inplace=True)

    if basis == 'X':
        for qubit in range(qc.num_qubits):
            meas_circ.h(qubit)
    elif basis == 'Y':
        for qubit in range(qc.num_qubits):
            meas_circ.sdg(qubit)
            meas_circ.h(qubit)
    elif basis == 'Z':
        pass
    else:
        raise ValueError("Basis must be 'X', 'Y', or 'Z'")
    
    # For 'Z' basis, no additional gates are needed
    meas_circ.measure(range(n), range(n))
    meas_circ.metadata = {'basis': basis}
    return meas_circ

N = 6
ghz6 = create_ghz_circuit(N)

circ_X = basis_measurement(ghz6, 'X')
circ_Y = basis_measurement(ghz6, 'Y')
circ_Z = basis_measurement(ghz6, 'Z')

circuits = [circ_X, circ_Y, circ_Z]

print("Circuits prepared for measurement in X, Y, and Z bases.")
print(circ_X.draw(output='text'))
print(circ_Y.draw(output='text'))
print(circ_Z.draw(output='text'))
# Out:
# Circuits prepared for measurement in X, Y, and Z bases.
#      ┌───┐                                         ┌───┐        ┌─┐
# q_0: ┤ H ├──■────■─────────■───────■────────────■──┤ H ├────────┤M├───
#      └───┘┌─┴─┐  │  ┌───┐  │  ┌─┐  │            │  └───┘        └╥┘
# q_1: ─────┤ X ├──┼──┤ H ├──┼──┤M├──┼────────────┼────────────────╫────
#           └───┘┌─┴─┐├───┤  │  └╥┘  │       ┌─┐  │                ║
# q_2: ──────────┤ X ├┤ H ├──┼───╫───┼───────┤M├──┼────────────────╫────
#                └───┘└───┘┌─┴─┐ ║   │  ┌───┐└╥┘  │   ┌─┐          ║
# q_3: ────────────────────┤ X ├─╫───┼──┤ H ├─╫───┼───┤M├──────────╫────
#                          └───┘ ║ ┌─┴─┐├───┤ ║   │   └╥┘      ┌─┐ ║
# q_4: ──────────────────────────╫─┤ X ├┤ H ├─╫───┼────╫───────┤M├─╫────
#                                ║ └───┘└───┘ ║ ┌─┴─┐  ║  ┌───┐└╥┘ ║ ┌─┐
# q_5: ──────────────────────────╫────────────╫─┤ X ├──╫──┤ H ├─╫──╫─┤M├
#                                ║            ║ └───┘  ║  └───┘ ║  ║ └╥┘
# c: 6/══════════════════════════╩════════════╩════════╩════════╩══╩══╩═
#                                1            2        3        4  0  5
#      ┌───┐                                          ┌─────┐┌───┐           ┌─┐»
# q_0: ┤ H ├──■────■───────────■───────────■───────■──┤ Sdg ├┤ H ├───────────┤M├»
#      └───┘┌─┴─┐  │  ┌─────┐  │   ┌───┐   │  ┌─┐  │  └─────┘└───┘           └╥┘»
# q_1: ─────┤ X ├──┼──┤ Sdg ├──┼───┤ H ├───┼──┤M├──┼──────────────────────────╫─»
#           └───┘┌─┴─┐├─────┤  │   ├───┤   │  └╥┘  │          ┌─┐             ║ »
# q_2: ──────────┤ X ├┤ Sdg ├──┼───┤ H ├───┼───╫───┼──────────┤M├─────────────╫─»
#                └───┘└─────┘┌─┴─┐┌┴───┴┐  │   ║   │   ┌───┐  └╥┘      ┌─┐    ║ »
# q_3: ──────────────────────┤ X ├┤ Sdg ├──┼───╫───┼───┤ H ├───╫───────┤M├────╫─»
#                            └───┘└─────┘┌─┴─┐ ║   │  ┌┴───┴┐  ║  ┌───┐└╥┘┌─┐ ║ »
# q_4: ──────────────────────────────────┤ X ├─╫───┼──┤ Sdg ├──╫──┤ H ├─╫─┤M├─╫─»
#                                        └───┘ ║ ┌─┴─┐├─────┤  ║  ├───┤ ║ └╥┘ ║ »
# q_5: ────────────────────────────────────────╫─┤ X ├┤ Sdg ├──╫──┤ H ├─╫──╫──╫─»
#                                              ║ └───┘└─────┘  ║  └───┘ ║  ║  ║ »
# c: 6/════════════════════════════════════════╩═══════════════╩════════╩══╩══╩═»
#                                              1               2        3  4  0 »
# «
# «q_0: ───
# «
# «q_1: ───
# «
# «q_2: ───
# «
# «q_3: ───
# «
# «q_4: ───
# «     ┌─┐
# «q_5: ┤M├
# «     └╥┘
# «c: 6/═╩═
# «      5
#      ┌───┐                                     ┌─┐
# q_0: ┤ H ├──■────■───────■───────■───────■─────┤M├───
#      └───┘┌─┴─┐  │  ┌─┐  │       │       │     └╥┘
# q_1: ─────┤ X ├──┼──┤M├──┼───────┼───────┼──────╫────
#           └───┘┌─┴─┐└╥┘  │  ┌─┐  │       │      ║
# q_2: ──────────┤ X ├─╫───┼──┤M├──┼───────┼──────╫────
#                └───┘ ║ ┌─┴─┐└╥┘  │  ┌─┐  │      ║
# q_3: ────────────────╫─┤ X ├─╫───┼──┤M├──┼──────╫────
#                      ║ └───┘ ║ ┌─┴─┐└╥┘  │  ┌─┐ ║
# q_4: ────────────────╫───────╫─┤ X ├─╫───┼──┤M├─╫────
#                      ║       ║ └───┘ ║ ┌─┴─┐└╥┘ ║ ┌─┐
# q_5: ────────────────╫───────╫───────╫─┤ X ├─╫──╫─┤M├
#                      ║       ║       ║ └───┘ ║  ║ └╥┘
# c: 6/════════════════╩═══════╩═══════╩═══════╩══╩══╩═
#                      1       2       3       4  0  5

# %%
from iqm.qiskit_iqm import IQMProvider

SHOTS = 1024 

provider = IQMProvider("https://resonance.meetiqm.com",
                       quantum_computer="garnet",
                       token="aJZeUpSK3smE5rBKnZmcOGrmDmBwWC68k0Z3AEQ+gEkBnBR9Gkxz4YDOlNha+WKz")
backend = provider.get_backend()

qc_transpiled = transpile(qc,backend)
job = backend.run(qc_transpiled, SHOTS=SHOTS)

result=job.result()

counts_X = result.get_counts(0)  # first circuit
counts_Y = result.get_counts(1)  # second circuit
counts_Z = result.get_counts(2)  # third circuit


print("Counts (X basis):", counts_X)
print("Counts (Y basis):", counts_Y)
print("Counts (Z basis):", counts_Z)

print(result.get_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from iqm.qiskit_iqm import IQMProvider
#       3 SHOTS = 1024
#       5 provider = IQMProvider("https://resonance.meetiqm.com",
#       6                        quantum_computer="emerald",
#       7                        token="aJZeUpSK3smE5rBKnZmcOGrmDmBwWC68k0Z3AEQ+gEkBnBR9Gkxz4YDOlNha+WKz")
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/qiskit_iqm/__init__.py:18
#      14 """Qiskit adapter for IQM's quantum computers."""
#      16 import warnings
# ---> 18 from iqm.qiskit_iqm.fake_backends import IQMErrorProfile, IQMFakeAdonis, IQMFakeAphrodite, IQMFakeApollo, IQMFakeDeneb
#      19 from iqm.qiskit_iqm.fake_backends.iqm_fake_backend import IQMFakeBackend
#      20 from iqm.qiskit_iqm.iqm_circuit import IQMCircuit
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/qiskit_iqm/fake_backends/__init__.py:16
#       1 # Copyright 2022-2023 Qiskit on IQM developers
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """Fake backends for simulating IQM quantum computers."""
# ---> 16 from .fake_adonis import IQMFakeAdonis
#      17 from .fake_aphrodite import IQMFakeAphrodite
#      18 from .fake_apollo import IQMFakeApollo
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/qiskit_iqm/fake_backends/fake_adonis.py:16
#       1 # Copyright 2022-2023 Qiskit on IQM developers
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """Fake backend for IQM's 5-qubit Adonis architecture."""
# ---> 16 from iqm.qiskit_iqm.fake_backends.iqm_fake_backend import IQMErrorProfile, IQMFakeBackend
#      18 from iqm.station_control.interface.models import StaticQuantumArchitecture
#      21 def IQMFakeAdonis() -> IQMFakeBackend:
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/qiskit_iqm/fake_backends/iqm_fake_backend.py:23
#      20 from itertools import permutations
#      21 from uuid import UUID
# ---> 23 from iqm.qiskit_iqm.iqm_backend import IQM_TO_QISKIT_GATE_NAME, IQMBackendBase
#      24 from iqm.qiskit_iqm.iqm_circuit_validation import validate_circuit
#      25 from iqm.qiskit_iqm.iqm_transpilation import IQMReplaceGateWithUnitaryPass
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/qiskit_iqm/iqm_backend.py:22
#      19 import logging
#      20 from typing import Final
# ---> 22 from iqm.iqm_client import ObservationFinder
#      23 from iqm.qiskit_iqm.iqm_target import IQMTarget
#      24 from qiskit.providers import BackendV2
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/iqm_client/__init__.py:21
#      18 import warnings
#      20 from iqm.iqm_client.errors import *  # noqa: F403
# ---> 21 from iqm.iqm_client.iqm_client import *  # noqa: F403
#      22 from iqm.iqm_client.models import *  # noqa: F403
#      23 from iqm.iqm_client.transpile import *  # noqa: F403
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/iqm_client/iqm_client.py:29
#      24 import warnings
#      26 from iqm.iqm_client.errors import (
#      27     CircuitValidationError,
#      28 )
# ---> 29 from iqm.iqm_client.models import CircuitCompilationOptions, CircuitJobParameters, validate_circuit
#      30 from iqm.iqm_client.validation import validate_circuit_instructions, validate_qubit_mapping
#      31 from iqm.iqm_server_client.iqm_server_client import (
#      32     DEFAULT_TIMEOUT_SECONDS,  # noqa: F401
#      33     IQMServerClientJob,
#      34     StrUUIDOrDefault,
#      35     _IQMServerClient,
#      36 )
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/iqm_client/models.py:213
#     209 from uuid import UUID
#     211 from pydantic import BaseModel, Field
# --> 213 from iqm.pulse import Circuit
#     214 from iqm.pulse.builder import build_quantum_ops
#     215 from iqm.station_control.interface.models import (
#     216     DDMode,
#     217     DDStrategy,
#    (...)    222     QubitMapping,
#     223 )
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/pulse/__init__.py:18
#      14 """Control pulses, gates and instruction schedules for quantum computers."""
#      16 from importlib.metadata import PackageNotFoundError, version
# ---> 18 from iqm.pulse.builder import CircuitOperation
#      19 from iqm.pulse.circuit_operations import Circuit
#      21 try:
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/pulse/builder.py:39
#      37 from exa.common.qcm_data.chip_topology import ChipTopology, sort_components
#      38 from iqm.pulse.base_utils import _dicts_differ, merge_dicts
# ---> 39 from iqm.pulse.gate_implementation import (
#      40     CompositeCache,
#      41     GateImplementation,
#      42     Locus,
#      43     OICalibrationData,
#      44     OILCalibrationData,
#      45     OpCalibrationDataTree,
#      46 )
#      47 from iqm.pulse.gates import _validate_implementation, get_implementation_class
#      48 from iqm.pulse.gates.default_gates import _deprecated_implementations, _deprecated_ops, _quantum_ops_library
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/iqm/pulse/gate_implementation.py:36
#      32 from uuid import uuid4
#      34 import numpy as np
# ---> 36 from exa.common.data.parameter import Parameter, Setting
#      37 from exa.common.data.setting_node import SettingNode
#      38 from exa.common.qcm_data.chip_topology import ChipTopology
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/exa/common/data/parameter.py:71
#      69 import numpy as np
#      70 from pydantic import model_validator
# ---> 71 import xarray as xr
#      73 from exa.common.control.sweep.sweep_values import SweepValues
#      74 from exa.common.data.base_model import BaseModel
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import groupers, testing, tutorial
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)     12     save_mfdataset,
#      13 )
#      14 from xarray.backends.zarr import open_zarr
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/groupers.py:17
#      14 import numpy as np
#      15 import pandas as pd
# ---> 17 from xarray.coding.cftime_offsets import BaseCFTimeOffset, _new_to_legacy_freq
#      18 from xarray.core import duck_array_ops
#      19 from xarray.core.coordinates import Coordinates, _coordinates_from_variable
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/coding/cftime_offsets.py:56
#      53 import pandas as pd
#      54 from packaging.version import Version
# ---> 56 from xarray.coding.cftimeindex import CFTimeIndex, _parse_iso8601_with_reso
#      57 from xarray.coding.times import (
#      58     _is_standard_calendar,
#      59     _should_cftime_be_used,
#      60     convert_time_or_go_back,
#      61     format_cftime_datetime,
#      62 )
#      63 from xarray.core.common import _contains_datetime_like_objects, is_np_datetime_like
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/coding/cftimeindex.py:54
#      51 import pandas as pd
#      52 from packaging.version import Version
# ---> 54 from xarray.coding.times import (
#      55     _STANDARD_CALENDARS,
#      56     cftime_to_nptime,
#      57     infer_calendar_name,
#      58 )
#      59 from xarray.core.common import _contains_cftime_datetimes
#      60 from xarray.core.options import OPTIONS
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/coding/times.py:14
#      11 import pandas as pd
#      12 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
# ---> 14 from xarray.coding.variables import (
#      15     SerializationWarning,
#      16     VariableCoder,
#      17     lazy_elemwise_func,
#      18     pop_to,
#      19     safe_setitem,
#      20     unpack_for_decoding,
#      21     unpack_for_encoding,
#      22 )
#      23 from xarray.core import indexing
#      24 from xarray.core.common import contains_cftime_datetimes, is_np_datetime_like
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/coding/variables.py:13
#      10 import numpy as np
#      11 import pandas as pd
# ---> 13 from xarray.core import dtypes, duck_array_ops, indexing
#      14 from xarray.core.variable import Variable
#      15 from xarray.namedarray.parallelcompat import get_chunked_array_type
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:37
#      34 from packaging.version import Version
#      35 from pandas.api.types import is_extension_array_dtype
# ---> 37 from xarray.core import dask_array_ops, dtypes, nputils
#      38 from xarray.core.options import OPTIONS
#      39 from xarray.core.utils import is_duck_array, is_duck_dask_array, module_available
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/core/dask_array_ops.py:3
#       1 from __future__ import annotations
# ----> 3 from xarray.core import dtypes, nputils
#       6 def dask_rolling_wrapper(moving_func, a, window, min_count=None, axis=-1):
#       7     """Wrapper to apply bottleneck moving window funcs on dask arrays"""
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/core/nputils.py:14
#      11 from xarray.namedarray import pycompat
#      13 # remove once numpy 2.0 is the oldest supported version
# ---> 14 if module_available("numpy", minversion="2.0.0.dev0"):
#      15     from numpy.lib.array_utils import (  # type: ignore[import-not-found,unused-ignore]
#      16         normalize_axis_index,
#      17     )
#      18 else:
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/xarray/namedarray/utils.py:58, in module_available(module, minversion)
#      55 if minversion is not None:
#      56     version = importlib.metadata.version(module)
# ---> 58     return Version(version) >= Version(minversion)
#      60 return True
#
# File ~/Documents/GitClones/Penntanglement-IQM/.venv/lib/python3.11/site-packages/packaging/version.py:200, in Version.__init__(self, version)
#     189 """Initialize a Version object.
#     190
#     191 :param version:
#    (...)    196     exception will be raised.
#     197 """
#     199 # Validate the version and parse it into pieces
# --> 200 match = self._regex.search(version)
#     201 if not match:
#     202     raise InvalidVersion(f"Invalid version: '{version}'")
#
# TypeError: expected string or bytes-like object, got 'NoneType'

# %%
def exp_XN_or_YN_from_counts(counts, n_qubits, shots):
    exp_value = 0
    for bitstring, count in counts.items():
        parity = sum(int(bit) for bit in bitstring) % 2
        if parity == 0:
            exp_value += count
        else:
            exp_value -= count
    return exp_value / shots

def exp_ZiZj_from_counts(counts, i, j, n_qubits, shots):
    """
    Compute <Z_i Z_j> from Z-basis counts.
    Eigenvalue = +1 if bits the same, -1 if different.
    Qiskit bitstring order: left char = qubit N-1, right char = qubit 0.
    """
    total = 0
    for bitstring, c in counts.items():
        # map qubit index -> character index
        # qubit 0 corresponds to rightmost character
        bit_i = int(bitstring[n_qubits - 1 - i])
        print(f"bit_i for qubit {i}: {bit_i}")
        bit_j = int(bitstring[n_qubits - 1 - j])
        print(f"bit_j for qubit {j}: {bit_j}")
        eigenvalue = 1 if bit_i == bit_j else -1
        total += eigenvalue * c
    return total / shots

N = 6
E_XN = exp_XN_or_YN_from_counts(counts_X, N, SHOTS)
E_YN = exp_XN_or_YN_from_counts(counts_Y, N, SHOTS)
E_ZiZj = exp_ZiZj_from_counts(counts_Z, 0, 1, N, SHOTS)
